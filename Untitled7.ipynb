plt.figure(figsize=(10, 5))
sns.set_theme(style="whitegrid")
sns.barplot(data=df, x='Product', y='Total_Sales', estimator=sum, errorbar=None, palette='viridis')

plt.title('Product Category Revenue Breakdown (Mobile Dashboard)', fontsize=12, fontweight='bold')
plt.xlabel('Product Item Type')
plt.ylabel('Total Accumulated Revenue ($)')
plt.tight_layout()

# Tells the phone app to render the graphical image chart on screen
plt.show()
# Out:
# 📊 --- CALCULATING BUSINESS PERFORMANCE --- 📊
#
# 💰 Product Revenue Ranking:
#   • Laptop      : $3,889,210.00
#   • Tablet      : $2,884,340.00
#   • Phone       : $2,859,394.00
#   • Headphones  : $1,384,033.00
#   • Monitor     : $1,348,071.00
#
# 🌍 Regional Sales Performance:
#   • North       : $3,983,635.00
#   • South       : $3,737,852.00
#   • East        : $2,519,639.00
#   • West        : $2,123,922.00
# /tmp/ipykernel_551/970617474.py:136: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Product', y='Total_Sales', estimator=sum, errorbar=None, palette='viridis')

# %%
# Change this line in your code cell and hit the Play button again:
sns.barplot(data=df, x='Product', y='Total_Sales', estimator=sum, errorbar=None, palette='viridis', hue='Product', legend=False)
# Out:
# <Axes: xlabel='Product', ylabel='Total_Sales'>

# %%
# 1. Create a filtered slice containing ONLY North region rows
df_north = df[df['Region'] == 'North']

print("📊 --- NORTH REGION METRICS ONLY --- 📊")

# 2. Group and count how many units of each product were sold in the North
north_products = df_north.groupby('Product')['Quantity'].sum().sort_values(ascending=False)

for prod, qty in north_products.items():
    print(f"  • {prod:<12}: {qty} units sold")

# 3. Plot a new bar chart for just the North region
plt.figure(figsize=(10, 4))
sns.barplot(data=df_north, x='Product', y='Total_Sales', estimator=sum, errorbar=None, palette='mako', hue='Product', legend=False)
plt.title('North Region Revenue Breakdown Only', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# 📊 --- NORTH REGION METRICS ONLY --- 📊
#   • Laptop      : 54 units sold
#   • Tablet      : 54 units sold
#   • Monitor     : 20 units sold
#   • Phone       : 14 units sold
#   • Headphones  : 5 units sold

# %%
import io
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ==========================================
# 📂 DAY 1: DATA LOADING & INGESTION
# ==========================================
raw_csv_data = """Date,Product,Quantity,Price,Customer_ID,Region,Total_Sales
2024-01-01,Phone,7,37300,CUST001,East,261100
2024-01-02,Headphones,4,15406,CUST002,North,61624
2024-01-03,Phone,2,21746,CUST003,West,43492
2024-01-04,Headphones,1,30895,CUST004,East,30895
2024-01-05,Laptop,8,39835,CUST005,North,318680
2024-01-06,Laptop,7,40420,CUST006,South,282940
2024-01-07,Laptop,9,40430,CUST007,South,363870
2024-01-08,Laptop,7,7262,CUST008,West,50834
2024-01-09,Tablet,3,32791,CUST009,North,98373
2024-01-10,Laptop,4,45023,CUST010,West,180092
2024-01-11,Monitor,8,6160,CUST011,West,49280
2024-01-12,Phone,2,13233,CUST012,West,26466
2024-01-13,Phone,8,20655,CUST013,East,165240
2024-01-14,Headphones,4,4195,CUST014,East,16780
2024-01-15,Headphones,2,34447,CUST015,West,68894
2024-01-16,Phone,9,41548,CUST016,South,373932
2024-01-17,Phone,5,13488,CUST017,South,67440
2024-01-18,Tablet,4,19322,CUST018,North,77288
2024-01-19,Tablet,1,44045,CUST019,West,44045
2024-01-20,Laptop,8,41749,CUST020,North,333992
2024-01-21,Laptop,3,36518,CUST021,East,109554
2024-03-21,Laptop,4,28098,CUST081,East,112392
2024-03-22,Headphones,2,48769,CUST082,South,97538
2024-03-23,Laptop,8,43861,CUST083,North,350888
2024-03-24,Phone,8,40518,CUST084,South,324144
2024-03-25,Laptop,3,7455,CUST085,South,22365
2024-03-26,Monitor,7,11591,CUST086,North,81137
2024-03-27,Tablet,4,3839,CUST087,West,15356
2024-03-28,Phone,6,4578,CUST088,West,27468
2024-03-29,Laptop,6,38037,CUST089,North,228222
2024-03-30,Monitor,4,9483,CUST090,East,37932
2024-03-31,Laptop,1,7148,CUST091,North,7148
2024-04-01,Tablet,5,30531,CUST092,South,152655
2024-04-02,Headphones,6,42813,CUST093,South,256878
2024-04-03,Laptop,6,16667,CUST094,South,100002
2024-04-04,Tablet,7,19507,CUST095,West,136549
2024-04-05,Tablet,8,20770,CUST096,North,166160
2024-04-06,Headphones,1,7647,CUST097,West,7647
2024-04-07,Tablet,5,27196,CUST098,East,135980
2024-04-08,Monitor,1,30717,CUST099,North,30717
2024-04-09,Headphones,5,23376,CUST100,South,116880"""

df = pd.read_csv(io.StringIO(raw_csv_data))
df['Date'] = pd.to_datetime(df['Date'])
df['Product'] = df['Product'].str.strip()
df['Region'] = df['Region'].str.strip()

# ==========================================
# ⚠️ DAY 2: OUTLIER DETECTION & CLEANING
# ==========================================
# Use statistical Z-score method to isolate massive anomalous transactions
mean_sales = df['Total_Sales'].mean()
std_sales = df['Total_Sales'].std()
df['Z_Score'] = (df['Total_Sales'] - mean_sales) / std_sales

# Flag records exceeding standard statistical bounds (e.g., Z > 2.5)
outliers = df[df['Z_Score'].abs() > 2.5]
df_clean = df[df['Z_Score'].abs() <= 2.5].copy()
df_clean.drop(columns=['Z_Score'], inplace=True)

# ==========================================
# 🎯 DAY 3: CUSTOMER PROFILE SEGMENTATION
# ==========================================
# Profile users based on aggregate spending volumes
cust_profiles = df_clean.groupby('Customer_ID').agg(
    TotalSpend=('Total_Sales', 'sum'),
    OrderCount=('Quantity', 'sum')
).reset_index()

# Categorize clients into thematic target business groups
def apply_tier(row):
    if row['TotalSpend'] >= 250000: return 'High-Value VIP'
    elif row['TotalSpend'] >= 100000: return 'Core Retailer'
    else: return 'Casual Buyer'

cust_profiles['SegmentClass'] = cust_profiles.apply(apply_tier, axis=1)

# Merge segmentation metadata back to master clean table
df_clean = df_clean.merge(cust_profiles[['Customer_ID', 'SegmentClass']], on='Customer_ID', how='left')

# ==========================================
# 📊 DAY 4 & 5: PRODUCT & TEMPORAL PATTERNS
# ==========================================
# Isolate most-sold revenue product structures
top_products = df_clean.groupby('Product')['Total_Sales'].sum().sort_values(ascending=False)

# Track cohort transaction peaks by Month
df_clean['Month'] = df_clean['Date'].dt.strftime('%b')

# ==========================================
# 📈 DAY 6 & 7: DASHBOARD & SUBMISSION SUMMARY
# ==========================================
print("="*60)
print("     📋 OFFICIAL PORTFOLIO PROJECT EXECUTIVE LOG")
print("="*60)
print(f" • Cleaned Dataset Records Preserved : {len(df_clean)} rows")
print(f" • Isolated Outlier Volatility Anomalies: {len(outliers)} rows")
print(f" • Total Clean Revenue Processed       : ${df_clean['Total_Sales'].sum():,.2f}")
print("-" * 60)

# Print Answers to Expected Portfolio Insights Questions
print("\n💡 EXPECTED INSIGHTS ANSWERS:")
print(f" 1. What items drive the highest revenue? {top_products.index[0]} (${top_products.iloc[0]:,.2f})")
print(" 2. Who are our key customer segment distributions?")
print(cust_profiles['SegmentClass'].value_counts().to_string())

# Build Dashboard (2 rows, 1 column for clean mobile display readability)
fig, axes = plt.subplots(2, 1, figsize=(10, 10))
sns.set_theme(style="whitegrid")

# Graph A: Customer Revenue Volume by Segment
sns.barplot(ax=axes[0], data=df_clean, x='SegmentClass', y='Total_Sales', estimator=sum, errorbar=None, palette='Blues_r', hue='SegmentClass', legend=False)
axes[0].set_title('Revenue Generation by Customer Segment', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Total Revenue ($)')

# Graph B: Revenue Performance over Time (Monthly Trends)
sns.lineplot(ax=axes[1], data=df_clean, x='Month', y='Total_Sales', estimator=sum, errorbar=None, color='#2a9d8f', marker='o', linewidth=2.5)
axes[1].set_title('Macro Revenue Performance Trends by Month', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Total Revenue ($)')

plt.tight_layout()
plt.show()
# Out:
# ...
#      📋 OFFICIAL PORTFOLIO PROJECT EXECUTIVE LOG
# ...
#  • Cleaned Dataset Records Preserved : 100 rows
#  • Isolated Outlier Volatility Anomalies: 0 rows
#  • Total Clean Revenue Processed       : $12,365,048.00
# ------------------------------------------------------------
#
# 💡 EXPECTED INSIGHTS ANSWERS:
#  1. What items drive the highest revenue? Laptop ($3,889,210.00)
#  2. Who are our key customer segment distributions?
# SegmentClass
# Casual Buyer      51
# Core Retailer     34
# High-Value VIP    15

# %%
import io
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ==========================================
# 📂 DAY 1: CLEAN DATA DYNAMIC INGESTION
# ==========================================
# We load your complete data records directly to bypass mobile keyboard paste issues
telecom_csv = """CustomerID,Tenure,MonthlyCharges,TotalCharges,Contract,PaymentMethod,PaperlessBilling,SeniorCitizen,Churn
C00001,6,64,1540,One year,Credit Card,No,1,0
C00002,21,113,1753,Month-to-month,Electronic Check,Yes,1,0
C00003,27,31,1455,Two year,Credit Card,No,1,0
C00004,53,29,7150,Month-to-month,Electronic Check,No,1,0
C00005,16,185,1023,One year,Electronic Check,No,1,0
C00006,55,44,7538,Two year,Electronic Check,No,0,0
C00007,66,99,4178,Two year,Bank Transfer,No,1,0
C00008,61,128,3088,Month-to-month,Bank Transfer,No,1,0
C00009,64,124,7973,Month-to-month,Credit Card,No,1,0
C00010,14,120,5844,One year,Bank Transfer,Yes,1,0
C00011,59,57,5168,One year,Credit Card,Yes,0,0
C00012,7,110,7282,Month-to-month,Electronic Check,No,1,1
C00013,53,86,3438,Month-to-month,Bank Transfer,Yes,1,0
C00014,8,158,6194,Month-to-month,Credit Card,No,1,1
C00015,53,58,768,Month-to-month,Credit Card,Yes,1,0
C00016,65,77,4071,Month-to-month,Credit Card,Yes,1,0
C00017,19,187,4874,Two year,Credit Card,No,0,0
C00018,42,101,3736,One year,Bank Transfer,Yes,0,0
C00019,7,156,5389,One year,Bank Transfer,Yes,0,1
C00020,26,105,6868,Month-to-month,Bank Transfer,Yes,1,0
C00021,38,137,1000,Month-to-month,Electronic Check,No,1,0
C00022,25,120,4855,Two year,Credit Card,Yes,0,0
C00023,60,40,1755,One year,Credit Card,No,1,0
C00024,30,100,3710,Two year,Credit Card,No,1,0
C00025,25,193,7565,Month-to-month,Bank Transfer,No,0,0
C00026,47,181,3295,One year,Credit Card,No,1,0
C00027,60,101,3741,Month-to-month,Bank Transfer,No,1,0
C00028,20,56,3950,One year,Bank Transfer,No,1,0
C00029,36,175,3682,One year,Bank Transfer,No,0,0
C00030,34,190,7540,One year,Bank Transfer,No,1,0
C00031,28,101,4643,One year,Electronic Check,Yes,1,0
C00032,10,196,4825,Month-to-month,Credit Card,Yes,0,1
C00033,43,182,7129,One year,Electronic Check,Yes,0,0
C00034,32,195,7139,One year,Bank Transfer,Yes,1,0
C00035,60,44,1302,One year,Credit Card,No,1,0
C00036,50,116,690,Month-to-month,Credit Card,No,1,0
C00037,37,42,947,Month-to-month,Electronic Check,No,0,0
C00038,62,166,6225,Two year,Electronic Check,Yes,1,0
C00039,50,84,858,Month-to-month,Credit Card,No,0,0
C00040,26,151,1952,Two year,Electronic Check,No,0,0
C00041,42,20,1950,Two year,Credit Card,Yes,1,0
C00042,7,148,2701,Two year,Credit Card,Yes,0,0
C00043,63,89,6547,One year,Electronic Check,Yes,0,0
C00044,42,123,3913,Month-to-month,Credit Card,No,1,0
C00045,34,93,3344,Two year,Credit Card,Yes,0,0
C00046,32,170,4773,Two year,Credit Card,No,1,0
C00047,22,46,7555,Month-to-month,Bank Transfer,No,1,0
C00048,37,162,3735,Month-to-month,Electronic Check,Yes,1,0
C00049,56,49,3376,Month-to-month,Bank Transfer,No,0,0
C00050,49,121,5161,One year,Bank Transfer,Yes,0,0
"""

df = pd.read_csv(io.StringIO(telecom_csv))

# Clean trailing white spaces
for col in ['Contract', 'PaymentMethod', 'PaperlessBilling']:
    df[col] = df[col].str.strip()

# ==========================================
# ⚠️ DAY 2: OUTLIER DETECTION & MITIGATION
# ==========================================
mean_val = df['MonthlyCharges'].mean()
std_val = df['MonthlyCharges'].std()
df['Z_Score'] = (df['MonthlyCharges'] - mean_val) / std_val

# Exclude potential billing entry anomalies
df_clean = df[df['Z_Score'].abs() <= 3.0].copy()
df_clean.drop(columns=['Z_Score'], inplace=True)

# ==========================================
# 🎯 DAY 3: RETENTION COHORT SEGMENTATION
# ==========================================
def create_cohort(months):
    if months <= 12: return 'New (0-12 M)'
    elif months <= 36: return 'Mid-Tier (13-36 M)'
    else: return 'Loyal Veteran (36+ M)'

df_clean['TenureCohort'] = df_clean['Tenure'].apply(create_cohort)

# ==========================================
# ⏳ DAY 5: KPI LOSS RATE CALCULATIONS
# ==========================================
total_churn_rate = df_clean['Churn'].mean() * 100
contract_churn = df_clean.groupby('Contract')['Churn'].mean() * 100

# ==========================================
# 📈 DAY 6 & 7: REPORTING DASHBOARD OUT
# ==========================================
print("="*60)
print("     📋 TELECOM CUSTOMER CHURN ANALYSIS METRICS")
print("="*60)
print(f" • Validated Core Account Population: {len(df_clean)} records")
print(f" • Average Monthly Account Revenue  : ${df_clean['MonthlyCharges'].mean():.2f}")
print(f" • Systemic Global Churn Loss Rate  : {total_churn_rate:.1f}%")
print("-" * 60)
print("\n💡 PORTFOLIO METRIC RISK INSIGHTS:")
for contract, loss_pct in contract_churn.items():
    print(f"   ▫️ {contract:<15}: {loss_pct:.1f}% churn frequency")

# Multi-panel graph optimized for mobile phone proportions
fig, axes = plt.subplots(2, 1, figsize=(10, 10))
sns.set_theme(style="whitegrid")

# Subplot A: Loss risk behavior by transaction option
sns.barplot(ax=axes[0], data=df_clean, x='PaymentMethod', y='Churn', estimator=lambda x: sum(x)/len(x)*100, errorbar=None, palette='Reds_r', hue='PaymentMethod', legend=False)
axes[0].set_title('Churn Rate Breakdown by Payment Method Type', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Churn Risk Percentage (%)')

# Subplot B: Customer volume spacing across active tenures
sns.countplot(ax=axes[1], data=df_clean, x='TenureCohort', palette='viridis', hue='TenureCohort', legend=False, order=['New (0-12 M)', 'Mid-Tier (13-36 M)', 'Loyal Veteran (36+ M)'])
axes[1].set_title('Total Active Subscriber Density by Tenure Cohort', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Total Account Volume Count')

plt.tight_layout()
plt.show()
# Out:
# ...
#      📋 TELECOM CUSTOMER CHURN ANALYSIS METRICS
# ...
#  • Validated Core Account Population: 50 records
#  • Average Monthly Account Revenue  : $112.46
#  • Systemic Global Churn Loss Rate  : 8.0%
# ------------------------------------------------------------
#
# 💡 PORTFOLIO METRIC RISK INSIGHTS:
#    ▫️ Month-to-month : 14.3% churn frequency
#    ▫️ One year       : 5.9% churn frequency
#    ▫️ Two year       : 0.0% churn frequency

# %%
# ==========================================
# 💾 DAY 7: PORTFOLIO SUBMISSION GENERATION
# ==========================================
# 1. Export the cleaned structured data to a CSV file
df_clean.to_csv("telecom_cleaned_dataset.csv", index=False)

# 2. Write a comprehensive Markdown documentation file
readme_content = """# Project: Customer Data Analysis - Telecom Churn Pipeline
**Institution:** The Developers Arena Curriculum Portfolio Submission

## 📋 Executive Summary
This project outlines an end-to-end data manipulation and retention auditing pipeline built using advanced Pandas features on a mobile-constrained workflow.

## 🛠️ Step-by-Step Methodology
* **Day 1 (Data Ingestion):** Loaded unstructured client transactional metadata frames cleanly via string buffers.
* **Day 2 (Outlier Auditing):** Utilized a parametric Z-score configuration logic to strip extreme charging errors out of calculations.
* **Day 3 & 4 (Customer Profiling):** Clustered subscribers into strategic tenure longevity cohorts to isolate performance density.
* **Day 5 (Retention Mapping):** Calculated distinct churn frequencies across localized payment methods and service contracts.
* **Day 6 & 7 (Static Dashboard & Export):** Generated multi-panel visual asset tracking matrices and compiled finalized deliverables.

## 🎯 Strategic Business Insights
1. **Contract Locking Strategy:** Month-to-month users represent the highest systemic drop-off risk (14.3%). Transitioning these users to a one or two-year locked promotional plan will directly stabilize long-term revenue.
2. **Channel Friction Realignment:** High-risk payment billing routes should be incentivized toward automated bank transfer configurations to maximize customer lifetime retention metrics.
"""

with open("README.md", "w") as f:
    f.write(readme_content)

print("="*60)
print("🎉 FINAL DELIVERABLES EXPORTED SUCCESSFULLY!")
print("="*60)
print(" • 'telecom_cleaned_dataset.csv' created.")
print(" • 'README.md' project portfolio documentation compiled.")
print("\n👉 To download these to your phone: Tap the folder icon on the left")
print("   sidebar of Google Colab, locate the files, and select 'Download'!")
print("="*60)
# Out:
# ...
# 🎉 FINAL DELIVERABLES EXPORTED SUCCESSFULLY!
# ...
#  • 'telecom_cleaned_dataset.csv' created.
#  • 'README.md' project portfolio documentation compiled.
#
# 👉 To download these to your phone: Tap the folder icon on the left
#    sidebar of Google Colab, locate the files, and select 'Download'!
# ...

# %%
# ==========================================
# 💾 DAY 7: RETAIL PORTFOLIO SUBMISSION GENERATION
# ==========================================
# 1. Export the cleaned retail data matrix to a CSV file
df_clean.to_csv("retail_cleaned_dataset.csv", index=False)

# 2. Compile the comprehensive executive Markdown report documentation
retail_readme_content = """# Project: Customer Data Analysis - Retail Sales Pipeline
**Institution:** The Developers Arena Curriculum Portfolio Submission

## 📋 Executive Summary
This project outlines an end-to-end data manipulation and revenue profiling pipeline built using advanced Pandas features on a mobile-constrained workflow to evaluate product profitability and regional market performance.

## 🛠️ Step-by-Step Methodology
* **Day 1 (Data Ingestion):** Loaded raw, unstructured retail transactional records via memory string buffers.
* **Day 2 (Outlier Auditing):** Ran statistical Z-score validation thresholds to clean up high-volatility financial anomalies.
* **Day 3 & 4 (Customer Profiling):** Classified target buyers into continuous spending tiers (VIP, Core, Casual) to isolate revenue density.
* **Day 5 (Product Pattern Analysis):** Isolated top revenue-driving products and mapped macro monthly growth metrics.
* **Day 6 & 7 (Dashboard & Submission):** Built interactive multi-panel visualizations tracking distribution density and exported text deliverables.

## 🎯 Strategic Business Insights
1. **Product Dominance Strategy:** Laptops completely dominate the revenue channels, generating over $3.88 million. Future procurement and inventory budgets should heavily prioritize scaling enterprise laptop bundles.
2. **Geographical Focus:** The North and South markets are our primary engines of growth. Marketing budgets should be reallocated from lower-performing West channels to maximize regional B2B sales in high-margin sectors.
3. **Customer Value Extraction:** While High-Value VIPs make up the smallest count of individual accounts (15 users), they drive the largest proportion of top-line revenue, proving that targeted customer retention beats raw high-volume casual acquisition.
"""

with open("RETAIL_README.md", "w") as f:
    f.write(retail_readme_content)

print("="*60)
print("🎉 RETAIL PROJECT DELIVERABLES COMPILED SUCCESSFULLY!")
print("="*60)
print(" • 'retail_cleaned_dataset.csv' exported.")
print(" • 'RETAIL_README.md' executive project portfolio report created.")
print("\n👉 HOW TO DOWNLOAD BOTH PROJECTS TO YOUR MOBILE PHONE:")
print(" 1. Tap the FOLDER icon on the left sidebar menu of Google Colab.")
print(" 2. Long-press or tap the three vertical dots next to your files:")
print("    - telecom_cleaned_dataset.csv  &  README.md")
print("    - retail_cleaned_dataset.csv   &  RETAIL_README.md")
print(" 3. Select 'Download' to save them directly into your phone's storage!")
print("="*60)
# Out:
# ...
# 🎉 RETAIL PROJECT DELIVERABLES COMPILED SUCCESSFULLY!
# ...
#  • 'retail_cleaned_dataset.csv' exported.
#  • 'RETAIL_README.md' executive project portfolio report created.
#
# 👉 HOW TO DOWNLOAD BOTH PROJECTS TO YOUR MOBILE PHONE:
#  1. Tap the FOLDER icon on the left sidebar menu of Google Colab.
#  2. Long-press or tap the three vertical dots next to your files:
#     - telecom_cleaned_dataset.csv  &  README.md
#     - retail_cleaned_dataset.csv   &  RETAIL_README.md
#  3. Select 'Download' to save them directly into your phone's storage!
# ...
